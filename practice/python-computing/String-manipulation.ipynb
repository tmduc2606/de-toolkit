# %% [markdown]
# # Working with strings
#
# Recall from the previous section that strings can be entered with single, double or triple quotes:
#
# ```python
#   'All', "of", '''these''', """are
#   valid strings"""
# ```
#
# **Unicode:** Python supports unicode strings - however for the most part this will be ignored in here. If you are workign in an editor that supports unicode you can use non-ASCII characters in strings (or even for variable names). Alternatively typing something like `"\u00B3"` will give you the string "³" (superscript-3).
#
# ## The Print Statement

# %% [markdown]
# As seen previously, The `print()` function prints all of its arguments as strings, separated by spaces and follows by a linebreak:
#
#     - print("Hello World")
#     - print("Hello",'World')
#     - print("Hello", <Variable>)
#
# Note that `print` is different in old versions of Python (2.7) where it was a statement and did not need parentheses around its arguments.

# %%
print("Hello","World")
# Out:
# Hello World

# %% [markdown]
# The print has some optional arguments to control where and how to print. This includes `sep` the separator (default space) and `end` (end charcter) and `file` to write to a file. When writing to a file, setting the argument `flush=True` may be useful to force the function to write the output immediately. Without this Python may buffer the output which helps to improve the speed for repeated calls to print(), but isn't helpful if you are, for example, wanting to see the output immediately during debugging)

# %%
print("Hello","World",sep='...',end='!!',flush=True)
# Out:
# Hello...World!!

# %% [markdown]
# ## String Formating
#
# There are lots of methods for formating and manipulating strings built into python. Some of these are illustrated here.
#
# String concatenation is the "addition" of two strings. Observe that while concatenating there will be no space between the strings.

# %%
string1='World'
string2='!'
print('Hello' + " " + string1 + string2)
# Out:
# Hello World!

# %% [markdown]
# **The `%` operator is used to format a string inserting the value that comes after**. It relies on the string containing a format specifier that identifies where to insert the value. The most common types of format specifiers are:
#
#     - %s -> string
#     - %d -> Integer
#     - %f -> Float
#     - %o -> Octal
#     - %x -> Hexadecimal
#     - %e -> exponential
#
# These will be very familiar to anyone who has ever written a C or Java program and follow nearly exactly the same rules as the [`printf()`](https://en.wikipedia.org/wiki/Printf_format_string) function.

# %%
print("Hello %s" % string1)
print("Actual Number = %d" %18)
print("Float of the number = %f" %18)
print("Octal equivalent of the number = %o" %18)
print("Hexadecimal equivalent of the number = %x" %18)
print("Exponential equivalent of the number = %e" %18)
# Out:
# Hello World
# Actual Number = 18
# Float of the number = 18.000000
# Octal equivalent of the number = 22
# Hexadecimal equivalent of the number = 12
# Exponential equivalent of the number = 1.800000e+01

# %% [markdown]
# When referring to multiple variables parentheses is used. Values are inserted in the order they appear in the parantheses (more on tuples in the next section)

# %%
print("Hello %s %s. This meaning of life is %d" %(string1,string2,42))
# Out:
# Hello World !. This meaning of life is 42

# %% [markdown]
# We can also specify the width of the field and the number of decimal places to be used. For example:

# %%
print('Print width 10: |%10s|'%'x')
print('Print width 10: |%-10s|'%'x') # left justified
print("The number pi = %.2f to 2 decimal places"%3.1415)
print("More space pi = %10.2f"%3.1415)
print("Pad pi with 0 = %010.2f"%3.1415) # pad with zeros
# Out:
# Print width 10: |         x|
# Print width 10: |x         |
# The number pi = 3.14 to 2 decimal places
# More space pi =       3.14
# Pad pi with 0 = 0000003.14

# %% [markdown]
# ## Other String Methods

# %% [markdown]
# Multiplying a string by an integer simply repeats it

# %%
print("Hello World! "*5)
# Out:
# Hello World! Hello World! Hello World! Hello World! Hello World!

# %% [markdown]
# #### Formatting
# Strings can be tranformed by a variety of functions that are all methods on a string. That is they are called by putting the function name with a `.` after the string. They include:
#
# * Upper vs lower case: `upper()`, `lower()`, `captialize()`, `title()` and `swapcase()` with mostly the obvious meaning. Note that `capitalize` makes the first letter of the string a capital only, while `title` selects upper case for the first letter of every word.
# * Padding strings: `center(n)`, `ljust(n)` and `rjust(n)` each place the string into a longer string of length n  padded by spaces (centered, left-justified or right-justified respectively). `zfill(n)` works similarly but pads with leading zeros.
# * Stripping strings: Often we want to remove spaces, this is achived with the functions `strip()`, `lstrip()`, and `rstrip()` respectively to remove from spaces from the both end, just left or just the right respectively. An optional argument can be used to list a set of other characters to be removed.

# %%
sentence ="heLLo wORLd!"
print(sentence.capitalize(),"vs", sentence.title())
print("upper: '%s'"%sentence.upper(),"lower: '%s'"%sentence.lower(),"and swapped: '%s'"%sentence.swapcase())
print('|%s|' % "Hello World".center(30)) # center in 30 characters
print('|%s|'% "     lots of space             ".strip()) # remove leading and trailing whitespace
print('%s without leading/trailing d,h,L or ! = |%s|',sentence.strip("dhL!"))
print("Hello World".replace("World","Class"))
print(sentence.replace("wORLd!", "Class!"))
# Out:
# Hello world! vs Hello World!
# upper: 'HELLO WORLD!' lower: 'hello world!' and swapped: 'HEllO WorlD!'
# |         Hello World          |
# |lots of space|
# %s without leading/trailing d,h,L or ! = |%s| eLLo wOR
# Hello Class
# heLLo Class!

# %%
# prompt: string formatting example

# Using % operator
print("Hello %s" % "World")
print("Actual Number = %d" % 18)
print("Float of the number = %f" % 18)
print("Octal equivalent of the number = %o" % 18)
print("Hexadecimal equivalent of the number = %x" % 18)
print("Exponential equivalent of the number = %e" % 18)

# Using .format() method
print("Hello {}".format("World"))
print("Actual Number = {}".format(18))
print("Float of the number = {}".format(18.0))
print("Octal equivalent of the number = {}".format(oct(18)))
print("Hexadecimal equivalent of the number = {}".format(hex(18)))
print("Exponential equivalent of the number = {}".format(18e3))

# Using f-strings
print(f"Hello {'World'}")
print(f"Actual Number = {18}")
print(f"Float of the number = {18.0}")
print(f"Octal equivalent of the number = {oct(18)}")
print(f"Hexadecimal equivalent of the number = {hex(18)}")
print(f"Exponential equivalent of the number = {18e3}")

# %% [markdown]
# #### Inspecting Strings
# There are also lost of ways to inspect or check strings. Examples of a few of these are given here:
#
# * Checking the start or end of a string: `startswith("string")` and `endswith("string")` checks if it starts/ends with the string given as argument
# * Capitalisation: There are boolean counterparts for all forms of capitalisation, such as `isupper()`, `islower()` and `istitle()`
# * Character type: does the string only contain the characters
#   * 0-9: `isdecimal()`. Note there is also `isnumeric()` and `isdigit()` which are effectively the same function except for certain unicode characters
#   * a-zA-Z: `isalpha()` or combined with digits: `isalnum()`
#   * non-control code: `isprintable()` accepts anything except '\n' an other ASCII control codes
#   * \t\n \r (white space characters): `isspace()`
#   * Suitable as variable name: `isidentifier()`
# * Find elements of string: `s.count(w)` finds the number of times w occurs in s, while `s.find(w)` and `s.rfind(w)` find the first and last position of the string w in s.

# %%
sentence = "Hello World"
print("The length of '%s' is"%sentence, len(sentence),"characters") # len() gives length
print(sentence.startswith("Hello") and sentence.endswith("World")) # check start/end
# count strings
print("There are %d 'l's but only %d World in %s" % (sentence.count('l'), sentence.count('World'),sentence))
print('"el" is at index',sentence.find('el'),"in",sentence) #index from 0 or -1
# Out:
# The length of 'Hello World' is 11 characters
# True
# There are 3 'l's but only 1 World in Hello World
# "el" is at index 1 in Hello World

# %%
# prompt: counting lines

# count the number of lines in a string
text = "This is a multiline\nstring\nwith multiple\nlines"
print(text.count("\n") + 1)

# %% [markdown]
# ## String comparison operations
# Strings can be compared in lexicographical order with the usual comparisons. In addition the `in` operator checks for substrings:

# %%
'abc' < 'bbc' <= 'bbc'
# Out:
# True

# %%
"ABC" in "This is the ABC of Python"
# Out:
# True

# %% [markdown]
# ## Accessing parts of strings

# %% [markdown]
# Strings can be indexed with square brackets. Indexing starts from zero in Python. And the `len()` function provides the length of a string

# %%
series = '123456789'
print("The string '%s' string is %d characters long" % (series, len(series)) )
print('First character of',series,'is',series[0])
print('Last character of',series,'is',series[len(series)-1])
# Out:
# The string '123456789' string is 9 characters long
# First character of 123456789 is 1
# Last character of 123456789 is 9

# %% [markdown]
# Negative indices can be used to start counting from the back

# %%
print('First character of',series,'is',series[-len(series)])
print('Last character of',series,'is',series[-1])
# Out:
# First character of 123456789 is 1
# Last character of 123456789 is 9

# %% [markdown]
# Finally a substring (range of characters) an be specified as using $a:b$ to specify the characters at index $a,a+1,\ldots,b-1$. Note that the last charcter is *not* included.

# %%
print("First three characters",series[0:3])
print("Next three characters",series[3:6])
# Out:
# First three characters 123
# Next three characters 456

# %%
series = '[8976453]'
print('id in integer', int(series[1:len(series)-1]), 'Is it True?', type(int(series[1:len(series)-1])))
# Out:
# id in integer 8976453 Is it True? <class 'int'>

# %% [markdown]
# An empty beginning and end of the range denotes the beginning/end of the string:

# %%
series = '123456789'
print("First three characters", series[:3])
print("Last three characters", series[-3:])
# Out:
# First three characters 123
# Last three characters 789

# %% [markdown]
# #### Breaking appart strings
# When processing text, the ability to split strings apart is particularly useful.
#
# * `partition(separator)`: breaks a string into three parts based on a separator
# * `split()`: breaks string into words separated by white-space (optionally takes a separator as argument)
# * `join()`: joins the result of a split using string as separator

# %%
s = "one -> two  ->  three"
print( s.partition("->") )
print( s.split() )
print( s.split(" -> ") )
print( ";".join( s.split(" -> ") ) )
# Out:
# ('one ', '->', ' two  ->  three')
# ['one', '->', 'two', '->', 'three']
# ['one', 'two ', ' three']
# one;two ; three

# %% [markdown]
# ## Strings are immutable
#
# It is important that strings are constant, immutable values in Python. While new strings can easily be created it is not possible to modify a string:

# %%
s='012345'
sX=s[:2]+'X'+s[3:] # this creates a new string with 2 replaced by X
print("creating new string",sX,"OK")
sX=s.replace('2','X') # the same thing
print(sX,"still OK")
# Out:
# creating new string 01X345 OK
# 01X345 still OK

# %%
s[2] = 'X' # an error!!!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c3ec2472a330> in <module>
# ----> 1 s[2] = 'X' # an error!!!
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# This is the error:
#
# `TypeError: 'str' object does not support item assignment`
#
# You should take care of that when debugging.

# %% [markdown]
# ## Advanced string processing
# For more advanced string processing there are many libraries available in Python including for example:
# * **re** for regular expression based searching and splitting of strings
# * **html** for manipulating HTML format text
# * **textwrap** for reformatting ASCII text
# * ... and many more

# %%
# prompt: Provide some exercises of string formatting in python

# String formatting exercises

# 1.  Using the % operator, format the following variables into a string:
name = "Alice"
age = 30
city = "New York"

# Expected output: "Alice is 30 years old and lives in New York."
print("%s is %d years old and lives in %s." % (name, age, city))


# 2. Use the .format() method to achieve the same output as exercise 1.
print("{} is {} years old and lives in {}.".format(name, age, city))


# 3.  Use f-strings to achieve the same output as exercise 1.
print(f"{name} is {age} years old and lives in {city}.")

# 4. Format a float number to two decimal places using the % operator.
pi = 3.14159265359
print("Pi to two decimal places: %.2f" % pi)

# 5. Format a float number to two decimal places using the .format() method.
print("Pi to two decimal places: {:.2f}".format(pi))

# 6. Format a float number to two decimal places using f-strings.
print(f"Pi to two decimal places: {pi:.2f}")


# 7. Center a string within a field of width 20.
string_to_center = "Hello"
print(f"|{string_to_center:^20}|")

# 8. Left-justify a string within a field of width 20.
print(f"|{string_to_center:<20}|")


# 9. Right-justify a string within a field of width 20.
print(f"|{string_to_center:>20}|")

#10. Pad a number with leading zeros to a total width of 5.
number_to_pad = 42
print(f"{number_to_pad:05}")

# 11. Combine string formatting with other string methods (e.g. upper(), lower())
print(f"Uppercase Name: {name.upper()}")


# 12. Use string formatting to display the current date and time.
import datetime
now = datetime.datetime.now()
print(f"Current date and time: {now:%Y-%m-%d %H:%M:%S}")

# 13. Format an integer to hexadecimal representation.
number = 255
print(f"Hexadecimal representation: {number:#x}")

#14.  Format a large number with thousands separators.
large_number = 1234567890
print(f"Large number with thousands separators: {large_number:,}")

# %%
# prompt: Give some exercises of string inspection in python

# String inspection exercises

# 1. Check if a string starts with a specific prefix.
string1 = "Hello World"
prefix = "Hello"
print(f"'{string1}' starts with '{prefix}': {string1.startswith(prefix)}")

# 2. Check if a string ends with a specific suffix.
suffix = "World"
print(f"'{string1}' ends with '{suffix}': {string1.endswith(suffix)}")


# 3. Check if a string is all uppercase.
uppercase_string = "HELLO"
print(f"'{uppercase_string}' is all uppercase: {uppercase_string.isupper()}")


# 4. Check if a string is all lowercase.
lowercase_string = "hello"
print(f"'{lowercase_string}' is all lowercase: {lowercase_string.islower()}")


# 5. Check if a string is a title-cased string.
title_string = "This Is A Title"
print(f"'{title_string}' is title-cased: {title_string.istitle()}")

# 6. Check if a string is composed of only digits.
digit_string = "12345"
print(f"'{digit_string}' is composed of digits: {digit_string.isdigit()}")

# 7. Check if a string is composed of only alphabetic characters.
alpha_string = "HelloWorld"
print(f"'{alpha_string}' is composed of alphabetic characters: {alpha_string.isalpha()}")


# 8. Check if a string is composed of only alphanumeric characters.
alnum_string = "HelloWorld123"
print(f"'{alnum_string}' is composed of alphanumeric characters: {alnum_string.isalnum()}")

# 9. Count the occurrences of a substring within a string.
string2 = "abcabcabc"
substring = "abc"
print(f"Number of occurrences of '{substring}' in '{string2}': {string2.count(substring)}")

# 10. Find the index of the first occurrence of a substring.
print(f"Index of first '{substring}' in '{string2}': {string2.find(substring)}")

# 11. Find the index of the last occurrence of a substring.
print(f"Index of last '{substring}' in '{string2}': {string2.rfind(substring)}")


# 12. Check if a string is printable.
printable_string = "Hello World!"
non_printable_string = "Hello\nWorld!"  # Contains a newline character
print(f"'{printable_string}' is printable: {printable_string.isprintable()}")
print(f"'{non_printable_string}' is printable: {non_printable_string.isprintable()}")

# 13. Check if a string is composed of only whitespace.
whitespace_string = "   \t\n  "
print(f"'{whitespace_string}' is composed of only whitespace: {whitespace_string.isspace()}")


#14. Check if a string is a valid identifier.
valid_identifier = "my_variable"
invalid_identifier = "123invalid"
print(f"'{valid_identifier}' is a valid identifier: {valid_identifier.isidentifier()}")
print(f"'{invalid_identifier}' is a valid identifier: {invalid_identifier.isidentifier()}")
